# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

import numpy as np

from tqdm import tqdm
from itertools import chain

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os 

import utils

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])
batch_size = 128
IMAGE_PATH = 'imagenet_valid/'

# %%
dataset = ImageFolder(IMAGE_PATH, transform)
train_set, test_set = utils.splitset(dataset)
train_loader = DataLoader(dataset=train_set, batch_size=batch_size, shuffle=True, num_workers=1, drop_last=True)
test_loader = DataLoader(dataset=test_set, batch_size=batch_size, shuffle=True, num_workers=1, drop_last=True)

# %%
inputs, _ = next(iter(train_loader))

# %%
utils.imshow(inputs[5])
