# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import utils

import introvae_model, models

import torchbearer as tb

from tensorboard_logging import ReconstructionsLogger, TensorBoardModelLogger, LatentSpaceReconLogger, RandomReconLogger
from torchbearer import Trial
from torchbearer.callbacks.tensor_board import TensorBoard
from utils import AEDatasetWrapper

import warnings
warnings.filterwarnings('ignore')

# %%
# Parameters:
params = {'batch_size': 128,
              'nEpoch': 50,
              'imgSize': 32,
              'zsize': 64,
              'depth': 0,
              'margin': 40,
              'alpha': 0.,
              'beta': 3,
              'gamma': 1,
              'lr': 1e-3,
              'pre': False,
              'com': 'simplule'
         }

    # Dataset construction
transform = transforms.Compose([
        transforms.ToTensor(),  # convert to tensor
    ])

device = "cuda:0" if torch.cuda.is_available() else "cpu"

# %%
trainset = AEDatasetWrapper(torchvision.datasets.CIFAR10('.', train=True, transform=transform, download=False))
trainloader = torch.utils.data.DataLoader(trainset, batch_size=params['batch_size'], shuffle=True, num_workers=4)
testset = AEDatasetWrapper(torchvision.datasets.CIFAR10('.', train=False, transform=transform, download=False))
testloader = torch.utils.data.DataLoader(testset, batch_size=params['batch_size'], shuffle=False, num_workers=4)

# %%
# construct the encoder, decoder and optimiser
iSize = params['imgSize']

vae = introvae_model.IntroVAE(iSize, params['zsize'], params['depth'], 
                      alpha=params['alpha'], beta=params['beta'], 
                      gamma=params['gamma'], margin=params['margin'],
                      lr=params['lr'])

tb_comment = params['com']
tbl = TensorBoard(write_graph=True, comment=tb_comment)
tbml = TensorBoardModelLogger(comment=tb_comment)
rsl = ReconstructionsLogger(comment=tb_comment, output_shape=(3, iSize, iSize))
lsrl = LatentSpaceReconLogger(comment=tb_comment, output_shape=(3, iSize, iSize), latent_dim=params['zsize'])
rrl = RandomReconLogger(comment=tb_comment, latent_dim=params['zsize'], output_shape=(3, iSize, iSize))
# Out:
# Encoder: [2, 3, 32, 32]=>[2, 16, 16, 16]=>[2, 32, 8, 8]=>[2, 64, 4, 4]=>[2, 64]  x 2
# Decoder: [64] => [2, 64, 4, 4]=>[2, 64, 8, 8]=>[2, 64, 16, 16]=>[2, 3, 32, 32]
# IntroVAE x: [2, 3, 32, 32] mu_: [2, 64] z: [2, 64] out: [2, 3, 32, 32]

# %%
encoder_step = models.encoder_step(pretrain=params['pre'])
encoder_loss = models.encoder_loss()

decoder_step = models.decoder_step()
decoder_loss = models.decoder_loss()

forward_step = models.forward_step()
recons_loss = models.recons_loss()

# %%
trial = Trial(vae, optimizer=None, criterion=None, 
              metrics=[recons_loss, encoder_loss, decoder_loss], 
              callbacks=[encoder_step, decoder_step, forward_step, tbl, tbml, rsl, lsrl, rrl]).to(device)
trial.with_generators(trainloader, val_generator=testloader)
# Out:
# --------------------- OPTIMZER ---------------------
# MockOptimizer ()
#
# -------------------- CRITERION ---------------------
# <function Trial.__init__.<locals>.criterion at 0x7f9fedf560d0>
#
# --------------------- METRICS ----------------------
# ['recons_loss', 'encoder_loss', 'decoder_loss']
#
# -------------------- CALLBACKS ---------------------
# ['models.encoder_step', 'models.decoder_step', 'models.forward_step', 'torchbearer.callbacks.tensor_board.TensorBoard', 'tensorboard_logging.TensorBoardModelLogger', 'tensorboard_logging.ReconstructionsLogger', 'tensorboard_logging.LatentSpaceReconLogger', 'tensorboard_logging.RandomReconLogger']
#
# ---------------------- MODEL -----------------------
# IntroVAE(
#   (enc): Encoder(
#     (net): Sequential(
#       (0): Conv2d(3, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#       (3): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       (4): ResBlk(
#         (net): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#           (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace)
#           (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (8): ReLU(inplace)
#         )
#         (shortcut): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#       )
#       (5): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       (6): ResBlk(
#         (net): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace)
#           (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (8): ReLU(inplace)
#         )
#         (shortcut): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#       )
#       (7): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       (8): ResBlk(
#         (net): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace)
#         )
#         (shortcut): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#         )
#       )
#       (9): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       (10): ResBlk(
#         (net): Sequential(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#           (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace)
#         )
#         (shortcut): Sequential()
#       )
#       (11): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       (12): Flatten()
#       (13): Linear(in_features=128, out_features=128, bias=True)
#     )
#   )
#   (dec): Decoder(
#     (net): Sequential(
#       (0): Linear(in_features=64, out_features=1024, bias=True)
#       (1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace)
#       (3): IntroReshape()
#       (4): ResBlk(
#         (net): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace)
#         )
#         (shortcut): Sequential()
#       )
#       (5): Upsample(scale_factor=2, mode=nearest)
#       (6): ResBlk(
#         (net): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace)
#         )
#         (shortcut): Sequential()
#       )
#       (7): Upsample(scale_factor=2, mode=nearest)
#       (8): ResBlk(
#         (net): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace)
#         )
#         (shortcut): Sequential()
#       )
#       (9): Upsample(scale_factor=2, mode=nearest)
#       (10): ResBlk(
#         (net): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace)
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (5): ReLU(inplace)
#         )
#         (shortcut): Sequential()
#       )
#       (11): Conv2d(64, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (12): Sigmoid()
#     )
#   )
# )

# %%
trial.run(params['nEpoch'])
# Out:
# 0/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.25it/s, decoder_loss=296.9, encoder_loss=321.6, recons_loss=98.01, running_decoder_loss=240.6, running_encoder_loss=266, running_recons_loss=79.39]
# 0/50(v): 100%|██████████| 79/79 [00:01<00:00, 40.91it/s, val_decoder_loss=234.1, val_encoder_loss=259.1, val_recons_loss=74.43]
# 1/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.21it/s, decoder_loss=217.8, encoder_loss=244.1, recons_loss=71.92, running_decoder_loss=200.1, running_encoder_loss=228.1, running_recons_loss=66.05]
# 1/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.62it/s, val_decoder_loss=211.1, val_encoder_loss=240.2, val_recons_loss=60.99]
# 2/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.26it/s, decoder_loss=191, encoder_loss=218.2, recons_loss=63.13, running_decoder_loss=185.2, running_encoder_loss=212.1, running_recons_loss=61.17]
# 2/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.88it/s, val_decoder_loss=168.9, val_encoder_loss=194.8, val_recons_loss=57.69]
# 3/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.26it/s, decoder_loss=176.5, encoder_loss=205.3, recons_loss=58.3, running_decoder_loss=171.4, running_encoder_loss=200.7, running_recons_loss=56.67]
# 3/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.47it/s, val_decoder_loss=157, val_encoder_loss=187.6, val_recons_loss=52.56]
# 4/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.26it/s, decoder_loss=167.6, encoder_loss=197.3, recons_loss=55.38, running_decoder_loss=165.6, running_encoder_loss=195.5, running_recons_loss=54.66]
# 4/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.61it/s, val_decoder_loss=198.8, val_encoder_loss=228.9, val_recons_loss=51.47]
# 5/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.24it/s, decoder_loss=161.5, encoder_loss=192.1, recons_loss=53.38, running_decoder_loss=158.4, running_encoder_loss=189.4, running_recons_loss=52.38]
# 5/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.58it/s, val_decoder_loss=157.8, val_encoder_loss=188, val_recons_loss=48.49]
# 6/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.26it/s, decoder_loss
50(v): 100%|██████████| 79/79 [00:01<00:00, 41.92it/s, val_decoder_loss=114.5, val_encoder_loss=153.4, val_recons_loss=35.5]
# 44/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.25it/s, decoder_loss=121.9, encoder_loss=162.5, recons_loss=40.41, running_decoder_loss=122.1, running_encoder_loss=162.9, running_recons_loss=40.51]
# 44/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.61it/s, val_decoder_loss=122.8, val_encoder_loss=163, val_recons_loss=35.6]
# 45/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.26it/s, decoder_loss=121.6, encoder_loss=161.9, recons_loss=40.3, running_decoder_loss=121.9, running_encoder_loss=162.3, running_recons_loss=40.36]
# 45/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.36it/s, val_decoder_loss=117.1, val_encoder_loss=156.3, val_recons_loss=35.81]
# 46/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.25it/s, decoder_loss=121.4, encoder_loss=161.8, recons_loss=40.24, running_decoder_loss=121.9, running_encoder_loss=162.4, running_recons_loss=40.42]
# 46/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.55it/s, val_decoder_loss=122.4, val_encoder_loss=162.4, val_recons_loss=35.8]
# 47/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.25it/s, decoder_loss=121.1, encoder_loss=161.7, recons_loss=40.17, running_decoder_loss=120.3, running_encoder_loss=160.8, running_recons_loss=39.93]
# 47/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.41it/s, val_decoder_loss=121.3, val_encoder_loss=162.5, val_recons_loss=35.44]
# 48/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.25it/s, decoder_loss=120.9, encoder_loss=161.5, recons_loss=40.1, running_decoder_loss=120.2, running_encoder_loss=160.6, running_recons_loss=39.86]
# 48/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.78it/s, val_decoder_loss=116.8, val_encoder_loss=156.1, val_recons_loss=35.57]
# 49/50(t): 100%|██████████| 391/391 [01:42<00:00,  4.26it/s, decoder_loss=120.7, encoder_loss=161.4, recons_loss=40, running_decoder_loss=120.4, running_encoder_loss=161, running_recons_loss=39.94]
# 49/50(v): 100%|██████████| 79/79 [00:01<00:00, 41.45it/s, val_decoder_loss=118, val_encoder_loss=160.6, val_recons_loss=35.12]
# [((391, 79),
#   {'running_recons_loss': 79.39180374145508,
#    'running_encoder_loss': 266.0420022583008,
#    'running_decoder_loss': 240.60554107666016,
#    'recons_loss': 98.0088844396879,
#    'encoder_loss': 321.5534504063599,
#    'decoder_loss': 296.865479569301,
#    'val_recons_loss': 74.42650188977206,
#    'val_encoder_loss': 259.1110534667969,
#    'val_decoder_loss': 234.1494140625}),
#  ((391, 79),
#   {'running_recons_loss': 66.04617942810059,
#    'running_encoder_loss': 228.07298065185546,
#    'running_decoder_loss': 200.07075561523436,
#    'recons_loss': 71.91610066055337,
#    'encoder_loss': 244.08907538606687,
#    'decoder_loss': 217.80542952203385,
#    'val_recons_loss': 60.993735880791384,
#    'val_encoder_loss': 240.205322265625,
#    'val_decoder_loss': 211.05740356445312}),
#  ((391, 79),
#   {'running_recons_loss': 61.17003349304199,
#    'running_encoder_loss': 212.1060299682617,
#    'running_decoder_loss': 185.16772430419923,
#    'recons_loss': 63.128317781726416,
#    'encoder_loss': 218.20034247591062,
#    'decoder_loss': 191.00122608857995,
#    'val_recons_loss': 57.690661176850526,
#    'val_encoder_loss': 194.84429931640625,
#    'val_decoder_loss': 168.89407348632812}),
#  ((391, 79),
#   {'running_recons_loss': 56.672888946533206,
#    'running_encoder_loss': 200.72153839111328,
#    'running_decoder_loss': 171.37925567626954,
#    'recons_loss': 58.297695189180885,
#    'encoder_loss': 205.27262355482486,
#    'decoder_loss': 176.5159318538578,
#    'val_recons_loss': 52.55974931354764,
#    'val_encoder_loss': 187.5835723876953,
#    'val_decoder_loss': 157.01309204101562}),
#  ((391, 79),
#   {'running_recons_loss': 54.65726036071777,
#    'running_encoder_loss': 195.45925231933595,
#    'running_decoder_loss': 165.60128967285155,
#    'recons_loss': 55.37749016803244,
#    'encoder_loss': 197.27414537512738,
#    'decoder_loss': 167.60726924808435,
#    'val_recons_loss': 51.471116078050834,
#    'val_encoder_loss': 228.90525817871094,
#    'val_decoder_loss': 198.795166015625}),
#  ((391, 79),
#   {'running_recons_loss': 52.382925491333005,
#    'running_encoder_loss': 189.3889633178711,
#    'running_decoder_loss': 158.37140075683592,
#    'recons_loss': 53.37988718330403,
#    'encoder_loss': 192.11827922538114,
#    'decoder_loss': 161.5130234350024,
#    'val_recons_loss': 48.48572564426857,
#    'val_encoder_loss': 188.01824951171875,
#    'val_decoder_loss': 157.84329223632812}),
#  ((391, 79),
#   {'running_recons_loss': 51.403226623535154,
#    'running_encoder_loss': 186.99033325195313,
#    'running_decoder_loss': 155.4387356567383,
#    'recons_loss': 52.30179309113251,
#    'encoder_loss': 189.85306757856208,
#    'decoder_loss': 158.34016996027563,
#    'val_recons_loss': 48.26835048047802,
#    'val_encoder_loss': 177.89064025878906,
#    'val_decoder_loss': 147.14938354492188}),
#  ((391, 79),
#   {'running_recons_loss': 51.27978042602539,
#    'running_encoder_loss': 187.23670135498048,
#    'running_decoder_loss': 155.27413330078124,
#    'recons_loss': 50.918201885564855,
#    'encoder_loss': 185.86104214953644,
#    'decoder_loss': 153.9048807675881,
#    'val_recons_loss': 46.5792559853083,
#    'val_encoder_loss': 167.26528930664062,
#    'val_decoder_loss': 135.30654907226562}),
#  ((391, 79),
#   {'running_recons_loss': 49.70183853149414,
#    'running_encoder_loss': 182.82041412353516,
#    'running_decoder_loss': 150.26649810791017,
#    'recons_loss': 50.35059482545194,
#    'encoder_loss': 184.97351526909168,
#    'decoder_loss': 152.47232555184522,
#    'val_recons_loss': 45.937817971917646,
#    'val_encoder_loss': 180.1352081298828,
#    'val_decoder_loss': 145.98057556152344}),
#  ((391, 79),
#   {'running_recons_loss': 48.561340408325194,
#    'running_encoder_loss': 179.8677734375,
#    'running_decoder_loss': 146.70253570556642,
#    'recons_loss': 49.33651713885919,
#    'encoder_loss': 182.26584978420715,
#    'decoder_loss': 149.19947541766155,
#    'val_recons_loss': 45.36185706416263,
#    'val_encoder_loss': 183.16883850097656,
#    'val_decoder_loss': 147.39706420898438}),
#  ((391, 79),
#   {'running_recons_loss': 48.48829643249512,
#    'running_encoder_loss': 180.9097671508789,
#    'running_decoder_loss': 146.6143328857422,
#    'recons_loss': 48.515570325924614,
#    'encoder_loss': 180.11316675054448,
#    'decoder_loss': 146.61034059646488,
#    'val_recons_loss': 43.996276034584525,
#    'val_encoder_loss': 180.5579376220703,
#    'val_decoder_loss': 146.25900268554688}),
#  ((391, 79),
#   {'running_recons_loss': 47.91189903259277,
#    'running_encoder_loss': 178.68071838378907,
#    'running_decoder_loss': 144.93904998779297,
#    'recons_loss': 48.06149106623267,
#    'encoder_loss': 179.36178424962037,
#    'decoder_loss': 145.38306655298413,
#    'val_recons_loss': 43.2208993646163,
#    'val_encoder_loss': 166.9041290283203,
#    'val_decoder_loss': 134.65188598632812}),
#  ((391, 79),
#   {'running_recons_loss': 47.43013465881348,
#    'running_encoder_loss': 177.95420654296876,
#    'running_decoder_loss': 143.48091247558594,
#    'recons_loss': 47.62136977407938,
#    'encoder_loss': 178.21036988085189,
#    'decoder_loss': 144.00636147111274,
#    'val_recons_loss': 43.9602003459689,
#    'val_encoder_loss': 176.1439208984375,
#    'val_decoder_loss': 141.35498046875}),
#  ((391, 79),
#   {'running_recons_loss': 47.29359725952148,
#    'running_encoder_loss': 177.2405856323242,
#    'running_decoder_loss': 142.6069564819336,
#    'recons_loss': 47.347701733679415,
#    'encoder_loss': 177.4125348259421,
#    'decoder_loss': 143.0039661729427,
#    'val_recons_loss': 43.04928704756725,
#    'val_encoder_loss': 178.45718383789062,
#    'val_decoder_loss': 144.01971435546875}),
#  ((391, 79),
#   {'running_recons_loss': 46.84513549804687,
#    'running_encoder_loss': 176.418876953125,
#    'running_decoder_loss': 141.68212890625,
#    'recons_loss': 46.83591776308806,
#    'encoder_loss': 176.2129370647928,
#    'decoder_loss': 141.47384586968386,
#    'val_recons_loss': 42.12688919260532,
#    'val_encoder_loss': 173.13494873046875,
#    'val_decoder_loss': 138.37310791015625}),
#  ((391, 79),
#   {'running_recons_loss': 45.81898239135742,
#    'running_encoder_loss': 174.0820169067383,
#    'running_decoder_loss': 138.50145431518555,
#    'recons_loss': 46.227721699668315,
#    'encoder_loss': 174.9566132528398,
#    'decoder_loss': 139.75635148070353,
#    'val_recons_loss': 41.26582143276553,
#    'val_encoder_loss': 173.36349487304688,
#    'val_decoder_loss': 138.48886108398438}),
#  ((391, 79),
#   {'running_recons_loss': 45.82204093933105,
#    'running_encoder_loss': 174.1586801147461,
#    'running_decoder_loss': 138.3528338623047,
#    'recons_loss': 45.84295407463522,
#    'encoder_loss': 174.09202064455621,
#    'decoder_loss': 138.52620901902924,
#    'val_recons_loss': 40.88450583928748,
#    'val_encoder_loss': 170.49386596679688,
#    'val_decoder_loss': 133.71658325195312}),
#  ((391, 79),
#   {'running_recons_loss': 45.225165634155275,
#    'running_encoder_loss': 172.92950134277345,
#    'running_decoder_loss': 136.78795455932618,
#    'recons_loss': 45.46276250580693,
#    'encoder_loss': 173.39712922469428,
#    'decoder_loss': 137.39551903219785,
#    'val_recons_loss': 40.571734223184706,
#    'val_encoder_loss': 174.8016815185547,
#    'val_decoder_loss': 139.21530151367188}),
#  ((391, 79),
#   {'running_recons_loss': 45.322046737670895,
#    'running_encoder_loss': 173.40172119140624,
#    'running_decoder_loss': 136.9757080078125,
#    'recons_loss': 45.12014060252158,
#    'encoder_loss': 172.6484393341767,
#    'decoder_loss': 136.3098707467394,
#    'val_recons_loss': 40.971082132073896,
#    'val_encoder_loss': 200.09799194335938,
#    'val_decoder_loss': 158.13153076171875}),
#  ((391, 79),
#   {'running_recons_loss': 44.800307235717774,
#    'running_encoder_loss': 172.13296447753908,
#    'running_decoder_loss': 135.23132644653322,
#    'recons_loss': 44.83329782705478,
#    'encoder_loss': 172.03901243087887,
#    'decoder_loss': 135.47241540699054,
#    'val_recons_loss': 39.902139011817646,
#    'val_encoder_loss': 161.58018493652344,
#    'val_decoder_loss': 122.05499267578125}),
#  ((391, 79),
#   {'running_recons_loss': 44.483282241821286,
#    'running_encoder_loss': 171.43006256103516,
#    'running_decoder_loss': 134.27248611450196,
#    'recons_loss': 44.39129654281889,
#    'encoder_loss': 171.1231047101033,
#    'decoder_loss': 134.0816407459776,
#    'val_recons_loss': 39.419244307505934,
#    'val_encoder_loss': 178.43045043945312,
#    'val_decoder_loss': 140.39308166503906}),
#  ((391, 79),
#   {'running_recons_loss': 43.719463119506834,
#    'running_encoder_loss': 169.5379653930664,
#    'running_decoder_loss': 131.97186981201173,
#    'recons_loss': 43.94894128199429,
#    'encoder_loss': 169.96620201637677,
#    'decoder_loss': 132.68900158582136,
#    'val_recons_loss': 39.51233402686783,
#    'val_encoder_loss': 158.6068115234375,
#    'val_decoder_loss': 120.23246765136719}),
#  ((391, 79),
#   {'running_recons_loss': 43.58613662719726,
#    'running_encoder_loss': 169.0819528198242,
#    'running_decoder_loss': 131.6835107421875,
#    'recons_loss': 43.84190370603596,
#    'encoder_loss': 169.9151262054053,
#    'decoder_loss': 132.4565065193664,
#    'val_recons_loss': 38.83081069173692,
#    'val_encoder_loss': 173.6065216064453,
#    'val_decoder_loss': 135.61434936523438}),
#  ((391, 79),
#   {'running_recons_loss': 43.679602432250974,
#    'running_encoder_loss': 169.68210662841796,
#    'running_decoder_loss': 132.01483154296875,
#    'recons_loss': 43.54889506269294,
#    'encoder_loss': 169.21013635503667,
#    'decoder_loss': 131.54363131706063,
#    'val_recons_loss': 39.05922505825381,
#    'val_encoder_loss': 171.1243133544922,
#    'val_decoder_loss': 132.60263061523438}),
#  ((391, 79),
#   {'running_recons_loss': 42.97061164855957,
#    'running_encoder_loss': 167.92640869140624,
#    'running_decoder_loss': 129.78813980102538,
#    'recons_loss': 43.18944989567827,
#    'encoder_loss': 168.4298707615689,
#    'decoder_loss': 130.41291442246694,
#    'val_recons_loss': 38.28681545016132,
#    'val_encoder_loss': 159.356689453125,
#    'val_decoder_loss': 121.93709564208984}),
#  ((391, 79),
#   {'running_recons_loss': 42.59946296691894,
#    'running_encoder_loss': 166.8301544189453,
#    'running_decoder_loss': 128.46885971069335,
#    'recons_loss': 42.94281015615634,
#    'encoder_loss': 167.85454775915122,
#    'decoder_loss': 129.63061665878882,
#    'val_recons_loss': 38.44870439360413,
#    'val_encoder_loss': 169.84408569335938,
#    'val_decoder_loss': 128.46029663085938}),
#  ((391, 79),
#   {'running_recons_loss': 42.57530212402344,
#    'running_encoder_loss': 166.76900451660157,
#    'running_decoder_loss': 128.55673568725587,
#    'recons_loss': 42.65118464789427,
#    'encoder_loss': 167.24538665537335,
#    'decoder_loss': 128.736064998695,
#    'val_recons_loss': 37.984103239035306,
#    'val_encoder_loss': 178.17874145507812,
#    'val_decoder_loss': 139.1407012939453}),
#  ((391, 79),
#   {'running_recons_loss': 43.01591659545898,
#    'running_encoder_loss': 168.49265808105469,
#    'running_decoder_loss': 129.69055572509765,
#    'recons_loss': 42.55228339192812,
#    'encoder_loss': 167.22448172410736,
#    'decoder_loss': 128.52281202623607,
#    'val_recons_loss': 38.01753717736353,
#    'val_encoder_loss': 179.8760223388672,
#    'val_decoder_loss': 138.99603271484375}),
#  ((391, 79),
#   {'running_recons_loss': 42.538482131958006,
#    'running_encoder_loss': 167.03284423828126,
#    'running_decoder_loss': 128.1522836303711,
#    'recons_loss': 42.35661972514199,
#    'encoder_loss': 166.64720430886348,
#    'decoder_loss': 127.84019895587736,
#    'val_recons_loss': 37.404533482805085,
#    'val_encoder_loss': 170.21022033691406,
#    'val_decoder_loss': 131.7640380859375}),
#  ((391, 79),
#   {'running_recons_loss': 42.370072021484376,
#    'running_encoder_loss': 166.99833435058594,
#    'running_decoder_loss': 127.76786224365235,
#    'recons_loss': 42.21930330671618,
#    'encoder_loss': 166.43908511891084,
#    'decoder_loss': 127.39608590987028,
#    'val_recons_loss': 37.07762034935287,
#    'val_encoder_loss': 184.56800842285156,
#    'val_decoder_loss': 143.1232147216797}),
#  ((391, 79),
#   {'running_recons_loss': 42.12951675415039,
#    'running_encoder_loss': 166.5477764892578,
#    'running_decoder_loss': 127.02704696655273,
#    'recons_loss': 41.99504924491239,
#    'encoder_loss': 165.95811115079525,
#    'decoder_loss': 126.7486057915651,
#    'val_recons_loss': 36.77241699605049,
#    'val_encoder_loss': 172.8243865966797,
#    'val_decoder_loss': 133.9620361328125}),
#  ((391, 79),
#   {'running_recons_loss': 41.49789657592773,
#    'running_encoder_loss': 164.55258697509765,
#    'running_decoder_loss': 125.32308044433594,
#    'recons_loss': 41.67060450092911,
#    'encoder_loss': 165.14018702202137,
#    'decoder_loss': 125.73576054487692,
#    'val_recons_loss': 36.85872587372985,
#    'val_encoder_loss': 169.951171875,
#    'val_decoder_loss': 127.74270629882812}),
#  ((391, 79),
#   {'running_recons_loss': 41.35539123535156,
#    'running_encoder_loss': 164.18914825439452,
#    'running_decoder_loss': 124.78931411743164,
#    'recons_loss': 41.787722282702354,
#    'encoder_loss': 165.62586815095008,
#    'decoder_loss': 126.18219091703214,
#    'val_recons_loss': 36.88820735110512,
#    'val_encoder_loss': 174.54898071289062,
#    'val_decoder_loss': 135.71746826171875}),
#  ((391, 79),
#   {'running_recons_loss': 41.95014533996582,
#    'running_encoder_loss': 166.24982971191406,
#    'running_decoder_loss': 126.40671813964843,
#    'recons_loss': 41.55787242099147,
#    'encoder_loss': 165.00864049418809,
#    'decoder_loss': 125.44941488983076,
#    'val_recons_loss': 36.65363683579843,
#    'val_encoder_loss': 171.32147216796875,
#    'val_decoder_loss': 132.31790161132812}),
#  ((391, 79),
#   {'running_recons_loss': 41.507045364379884,
#    'running_encoder_loss': 165.34089447021483,
#    'running_decoder_loss': 125.24176528930664,
#    'recons_loss': 41.44043955107784,
#    'encoder_loss': 164.73835336826647,
#    'decoder_loss': 125.02634022120014,
#    'val_recons_loss': 36.55264576779136,
#    'val_encoder_loss': 178.78445434570312,
#    'val_decoder_loss': 136.814208984375}),
#  ((391, 79),
#   {'running_recons_loss': 41.251761779785156,
#    'running_encoder_loss': 163.93497100830078,
#    'running_decoder_loss': 124.38355697631836,
#    'recons_loss': 41.28338531338041,
#    'encoder_loss': 164.29041214184383,
#    'decoder_loss': 124.57354744133133,
#    'val_recons_loss': 36.401024637343006,
#    'val_encoder_loss': 158.658447265625,
#    'val_decoder_loss': 117.75669860839844}),
#  ((391, 79),
#   {'running_recons_loss': 41.230026702880856,
#    'running_encoder_loss': 163.8072671508789,
#    'running_decoder_loss': 124.23544387817383,
#    'recons_loss': 41.23958433497592,
#    'encoder_loss': 164.27380753539103,
#    'decoder_loss': 124.41162363037733,
#    'val_recons_loss': 36.4410218347477,
#    'val_encoder_loss': 181.7681121826172,
#    'val_decoder_loss': 141.70864868164062}),
#  ((391, 79),
#   {'running_recons_loss': 41.47969261169433,
#    'running_encoder_loss': 165.2218994140625,
#    'running_decoder_loss': 125.03811904907226,
#    'recons_loss': 40.99722359308501,
#    'encoder_loss': 163.61023565814318,
#    'decoder_loss': 123.66718809318054,
#    'val_recons_loss': 36.481628224819524,
#    'val_encoder_loss': 164.17263793945312,
#    'val_decoder_loss': 124.75407409667969}),
#  ((391, 79),
#   {'running_recons_loss': 40.833832550048825,
#    'running_encoder_loss': 163.0772918701172,
#    'running_decoder_loss': 123.02069717407227,
#    'recons_loss': 40.89120197540049,
#    'encoder_loss': 163.2974127649956,
#    'decoder_loss': 123.35758523380055,
#    'val_recons_loss': 36.2410835072964,
#    'val_encoder_loss': 163.47183227539062,
#    'val_decoder_loss': 121.9687728881836}),
#  ((391, 79),
#   {'running_recons_loss': 40.865786972045896,
#    'running_encoder_loss': 163.50517852783204,
#    'running_decoder_loss': 123.49378326416016,
#    'recons_loss': 40.86901683758592,
#    'encoder_loss': 163.44173000169837,
#    'decoder_loss': 123.3996535396332,
#    'val_recons_loss': 36.13215313682073,
#    'val_encoder_loss': 160.5621337890625,
#    'val_decoder_loss': 119.92225646972656}),
#  ((391, 79),
#   {'running_recons_loss': 40.89268363952637,
#    'running_encoder_loss': 163.43450134277344,
#    'running_decoder_loss': 123.31931991577149,
#    'recons_loss': 40.682759336193506,
#    'encoder_loss': 162.73267421088255,
#    'decoder_loss': 122.76774669364285,
#    'val_recons_loss': 36.02582714225672,
#    'val_encoder_loss': 164.9393310546875,
#    'val_decoder_loss': 123.27267456054688}),
#  ((391, 79),
#   {'running_recons_loss': 40.61963966369629,
#    'running_encoder_loss': 163.00591888427735,
#    'running_decoder_loss': 122.66417861938477,
#    'recons_loss': 40.77258699812243,
#    'encoder_loss': 163.2272650677225,
#    'decoder_loss': 123.07270188587705,
#    'val_recons_loss': 36.13693092442766,
#    'val_encoder_loss': 173.6218719482422,
#    'val_decoder_loss': 132.09495544433594}),
#  ((391, 79),
#   {'running_recons_loss': 40.6938525390625,
#    'running_encoder_loss': 163.52078826904298,
#    'running_decoder_loss': 122.77681671142578,
#    'recons_loss': 40.570780097980936,
#    'encoder_loss': 162.80560478347036,
#    'decoder_loss': 122.43901157623057,
#    'val_recons_loss': 36.11938790429996,
#    'val_encoder_loss': 168.27203369140625,
#    'val_decoder_loss': 125.72917175292969}),
#  ((391, 79),
#   {'running_recons_loss': 40.706493606567385,
#    'running_encoder_loss': 162.6750631713867,
#    'running_decoder_loss': 122.51621704101562,
#    'recons_loss': 40.44748191150558,
#    'encoder_loss': 162.34286920493827,
#    'decoder_loss': 121.98799650382507,
#    'val_recons_loss': 35.49826006346111,
#    'val_encoder_loss': 153.40582275390625,
#    'val_decoder_loss': 114.54055786132812}),
#  ((391, 79),
#   {'running_recons_loss': 40.510422439575194,
#    'running_encoder_loss': 162.86542266845703,
#    'running_decoder_loss': 122.09740997314454,
#    'recons_loss': 40.40711986805167,
#    'encoder_loss': 162.47133287200538,
#    'decoder_loss': 121.91865767847241,
#    'val_recons_loss': 35.60032704510266,
#    'val_encoder_loss': 163.04934692382812,
#    'val_decoder_loss': 122.77719116210938}),
#  ((391, 79),
#   {'running_recons_loss': 40.359286041259764,
#    'running_encoder_loss': 162.29208526611328,
#    'running_decoder_loss': 121.89125015258789,
#    'recons_loss': 40.30154140891931,
#    'encoder_loss': 161.91201099288432,
#    'decoder_loss': 121.59275041272878,
#    'val_recons_loss': 35.805896662458586,
#    'val_encoder_loss': 156.31639099121094,
#    'val_decoder_loss': 117.10469055175781}),
#  ((391, 79),
#   {'running_recons_loss': 40.41731719970703,
#    'running_encoder_loss': 162.41799438476562,
#    'running_decoder_loss': 121.93253494262696,
#    'recons_loss': 40.23983863186653,
#    'encoder_loss': 161.79477436036404,
#    'decoder_loss': 121.35005993855273,
#    'val_recons_loss': 35.797463332550436,
#    'val_encoder_loss': 162.4421844482422,
#    'val_decoder_loss': 122.35273742675781}),
#  ((391, 79),
#   {'running_recons_loss': 39.93406578063965,
#    'running_encoder_loss': 160.82282409667968,
#    'running_decoder_loss': 120.28796600341796,
#    'recons_loss': 40.17118288123089,
#    'encoder_loss': 161.6968994140625,
#    'decoder_loss': 121.11943819089923,
#    'val_recons_loss': 35.43941034244585,
#    'val_encoder_loss': 162.54307556152344,
#    'val_decoder_loss': 121.29869079589844}),
#  ((391, 79),
#   {'running_recons_loss': 39.86441963195801,
#    'running_encoder_loss': 160.64073883056642,
#    'running_decoder_loss': 120.19451400756836,
#    'recons_loss': 40.10283009170571,
#    'encoder_loss': 161.48459326702616,
#    'decoder_loss': 120.91967234892003,
#    'val_recons_loss': 35.56565586524674,
#    'val_encoder_loss': 156.08287048339844,
#    'val_decoder_loss': 116.79531860351562}),
#  ((391, 79),
#   {'running_recons_loss': 39.944411773681644,
#    'running_encoder_loss': 160.95232513427734,
#    'running_decoder_loss': 120.40041564941406,
#    'recons_loss': 40.00338888534195,
#    'encoder_loss': 161.41686016580334,
#    'decoder_loss': 120.66429218184918,
#    'val_recons_loss': 35.12429300139222,
#    'val_encoder_loss': 160.58518981933594,
#    'val_decoder_loss': 117.98486328125})]
